# %%
import pandas as pd

df_income = pd.read_excel("../data/raw/borough_income_taxpayers.xlsx")

df_income.head()
# Out:
#         Name HMRC Survey of Personal Incomes  Unnamed: 2 Unnamed: 3
# 0  ShortName                             SPI         NaN        NaN
# 1        NaN                             NaN         NaN        NaN
# 2        NaN                             NaN         NaN        NaN
# 3        NaN                             NaN         NaN        NaN
# 4      Theme           Employment and Skills         NaN        NaN

# %%
import os

os.listdir("../data/raw")
# Out:
# ['borough_crime_historical.csv',
#  'borough_income_taxpayers.xlsx',
#  'borough_ptai_2015.csv',
#  'pp-2018.csv',
#  'pp-2019.csv',
#  'pp-2020.csv',
#  'pp-2021.csv',
#  'pp-2022.csv',
#  'pp-2023.csv',
#  'pp-2024.csv',
#  'pp-2025.csv']

# %%
excel_file = pd.ExcelFile("../data/raw/borough_income_taxpayers.xlsx")

excel_file.sheet_names
# Out:
# ['Metadata', 'Total Income']

# %%
import pandas as pd

df_income = pd.read_excel(
    "../data/raw/borough_income_taxpayers.xlsx",
    sheet_name="Total Income"
)

df_income.head()
# Out:
#   Unnamed: 0            Unnamed: 1                1999-00 Unnamed: 3  \
# 0       Code                  Area  Number of Individuals     Mean £
# 1        NaN                   NaN                    NaN        NaN
# 2  E09000001        City of London                  10000     109800
# 3  E09000002  Barking and Dagenham                  62000      16200
# 4  E09000003                Barnet                 161000      26800
#
#   Unnamed: 4                2000-01 Unnamed: 6 Unnamed: 7  \
# 0   Median £  Number of Individuals     Mean £   Median £
# 1        NaN                    NaN        NaN        NaN
# 2      40400                  10000     137000      65000
# 3      15100                  71000      18100      15600
# 4      18700                 156000      30800      19400
#
#                  2001-02 Unnamed: 9  ... Unnamed: 64                2021-22  \
# 0  Number of Individuals     Mean £  ...    Median £  Number of Individuals
# ...

# %%
df_income = pd.read_excel(
    "../data/raw/borough_income_taxpayers.xlsx",
    sheet_name="Total Income",
    header=[0, 1]
)

df_income.head()
# Out:
#   Unnamed: 0_level_0    Unnamed: 1_level_0               1999-00            \
#                 Code                  Area Number of Individuals    Mean £
# 0                NaN                   NaN                   NaN       NaN
# 1          E09000001        City of London               10000.0  109800.0
# 2          E09000002  Barking and Dagenham               62000.0   16200.0
# 3          E09000003                Barnet              161000.0   26800.0
# 4          E09000004                Bexley              105000.0   20500.0
#
#                          2000-01                                  2001-02  \
#   Median £ Number of Individuals    Mean £ Median £ Number of Individuals
# 0      NaN                   NaN       NaN      NaN                   NaN
# 1  40400.0               10000.0  137000.0  65000.0               12000.0
# 2  15100.0               71000.0   18100.0  15600.0               56000.0
# ...
